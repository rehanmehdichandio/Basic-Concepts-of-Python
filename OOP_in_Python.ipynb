# %% [markdown]
# <a href="https://colab.research.google.com/github/rehanmehdichandio/Basic-Concepts-of-Python/blob/main/OOP_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Class and Objects**
#
# Class is the blueprint.
#
# Object is the instance of the class

# %%
class Atm:

  #constructor (special function ->
  # -> Super power -> No need to call to execute)
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()
    # print('main to execute hogya')
  def menu(self):
    user_input = input("""
    Hi How can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)
    if user_input == '1':
      #create pin
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      #withdraw
      pass
    else:
      exit()

   #CreatePin
  def create_pin(self):
    user_pin = input('Enter your pin')
    self.pin = user_pin

    user_balance = int(input('Enter balance'))
    self.balance =  user_balance

    print('Pin created successfully')
    self.menu()
  # Change Pin
  def change_pin(self):
    old_pin = input('Enter old pin')

    if old_pin == self.pin:
      #Let him change the pin
      new_pin = input('Enter new pin')
      self.pin = new_pin
      print('Pin change successfully')
      self.menu()
    else:
      print('Pin incorrect')
      self.menu()
# Check Balance
    def check_balance(self):
     user_pin = input('Enter your pin')
     if user_pin == self.pin:
       print('Your balance is ', self.balance)
     else:
       print('Pin incorrect')
       self.menu()

      #wITHDRAW
    def withdraw(self):
      user_pin = input('Enter the pin')
      if user_pin == self.pin:
        #Allow to withdraw
        amount = int(input('Enter the amount'))
        if amount <= self.balance:
          self.balance = self.balance - amount
          print('Withdrawl successful', self.balance)
        else:
          print('Insufficient balance')
      else:
         print('Pin incorrect')

# %%
obj = Atm()
# Out:
#     Hi How can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin123
# Enter balance10000
# Pin created successfully
#
#     Hi How can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4

# %% [markdown]
# **Self**
#
# self ek object  ehota hai jo class h functions/modules ko communicate krny k liye istemal hota hai. Used for Enter Class Communication

# %%
#How to create our own data type.
#Create a fraction Data Type

#paramaterized Constructor
class Fraction:
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num, self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den
    return '{}/{}'.format(new_num, new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den
    return '{}/{}'.format(new_num, new_den)

  def __mul__(self,other):
    new_num = self.num*other.num
    new_den = self.den*other.den
    return '{}/{}'.format(new_num, new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num
    return '{}/{}'.format(new_num, new_den)

# %%
fr1 = Fraction(2,3)

# %%
print(fr1)
# Out:
# 2/3

# %%
fr2 = Fraction(1,2)

# %%
print(fr2)
# Out:
# 1/2

# %%
print(fr1+fr2)
# Out:
# 7/6

# %%
print(fr1-fr2)
# Out:
# 1/6

# %%
print(fr1*fr2)
# Out:
# 2/6

# %%
print(fr1 / fr2)
# Out:
# 4/3

# %% [markdown]
# **OOP part-2**
#
# Write OOP classes to handle the following scenarios:
#
# *   A user can create and view 2D Coordinates
# *   A user can find out the distance between 2 coordinates
# *   A user can find the distance of a cordinate from origin
# *   A user can chceck if a poin lies on a given line
# *   A user can find the distance between a given 2D point and a given line

# %%
class Point:
  def __init__(self, x, y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod, self.y_cod)

  def euclidian_distance(self,other):
    x = (self.x_cod - other.x_cod)**2
    y = (self.x_cod - other.x_cod)**2
    return (x+y)**0.5

  def distance_from_origin(self):
    return (self.x_cod**2 + self.y_cod**2)**0.5
    #return self.euclidian_distance(Point(0,0))

class Line:
  def __init__(self, A,B,C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A, self.B, self.C)

  def point_on_Line(line, point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return "lies on the line"
    else:
      return "does not lie on the line"

# %%
# p1 = Point(0,0)
# p2 = Point(1,1)

#p1.euclidian_distance(p2)
p1.distance_from_origin()
# p2.distance_from_origin()

l1 = Line(1,2,-6)
p1 = Point(2,2)
print(l1)
l1.point_on_Line(p1)
# Out:
# 1x + 2y + -6 = 0
# 'lies on the line'

# %% [markdown]
# How Objects Access Attributes

# %%
class Person:

  def __init__(self, name_input, country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'Pakistan':
      print('Assalam o Alaikum', self.name )
    elif self.country == 'India':
      print('Namaste', self.name)
    else:
      print('Hello', self.name)

# %%
p = Person('Rehan', 'Pakistan')

p.greet()
# Out:
# Assalam o Alaikum Rehan

# %% [markdown]
# **Attribute ceation outside of the class**

# %%
p.gender = 'male'

# %%
p.gender
# Out:
# 'male'

# %% [markdown]
# **Reference Variable**
#
#
# *   Reference Variable hold objects
# *   We can create objects with reference variable as well
# *   An object can have multiple reference variables
# *   Assigning a new reference variable to an existing object does not create a new object

# %%
#Object withour reference variable

class Person:

  def __init__(self):
    self.name = 'Rehan'
    self.gender = 'male'

p = Person() #p is not the object it holds the address of object
q = p

# %%
print(id(p))
print(id(q))
# Out:
# 133323846714720
# 133323846714720

# %%
class Person:
  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

#outside the class--> Function
def greet(person):
  print('Hi my name is ', person.name, 'and I am a ', person.gender)
  p1 = Person('Ayesha', 'Female')
  return p1

p = Person('Rehan', 'Male')
x = greet(p)

print(x.name)
print(x.gender)
# Out:
# Hi my name is  Rehan and I am a  Male
# Ayesha
# Female

# %% [markdown]
# **Encapsulation**

# %%
#instance variable -->
#a varible who has different value for different objects

class Person:

  def __init__(self, name_input, country_input):
    self.name = name_input
    self.country = country_input

p1 = Person('Rehan', 'Pakistan')
p2 = Person('Ayesha', 'Pakistan')

# %%
p1.name
# Out:
# 'Rehan'

# %%
#__ refers to private


class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 138267207178128

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance(10000)

# %%
obj.get_balance()
# Out:
# 10000

# %%
obj.set_balance("hehehe")
# Out:
# beta bahot maarenge

# %%
obj.get_balance()
# Out:
# 10000

# %%
obj.withdraw()
# Out:
# enter the pin
# enter the amount5000
# withdrawl successful.balance is 5000

# %% [markdown]
# **Collection of Objects**

# %%
#list
class Person:
  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

p1 = Person('Rehan', 'Male')
p2 = Person('Ayesha', 'Female')
p3 = Person('Jamshed', 'Male')

L= [p1,p2,p3]

print(L)

for i in L:
  print(i.name, i.gender)
# Out:
# [<__main__.Person object at 0x7dc0d7c49640>, <__main__.Person object at 0x7dc0d7c4a8d0>, <__main__.Person object at 0x7dc0d7c4b470>]
# Rehan Male
# Ayesha Female
# Jamshed Male

# %%
#dict
class Person:
  def __init__(self, name, gender):
    self.name = name
    self.gender = gender

p1 = Person('Rehan', 'Male')
p2 = Person('Ayesha', 'Female')
p3 = Person('Jamshed', 'Male')

d= {'p1':p1,'p2':p2, 'p3':p3}

print(d)

for i in d:
  print(d[i].name, d[i].gender)
# Out:
# {'p1': <__main__.Person object at 0x7dc0d7c49370>, 'p2': <__main__.Person object at 0x7dc0d7c98a10>, 'p3': <__main__.Person object at 0x7dc0d7c98bf0>}
# Rehan Male
# Ayesha Female
# Jamshed Male

# %% [markdown]
# **Static Variables**

# %%
#Instance variable ka value har object k liye different hota hai
# Instance variable object k liye hota hai

#static variable ka value sb objects k liye same hota hai
#static varibale class k liye hot hai
class Atm:
  __counter = 1 # static variable

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0

    #static variable for Customer ID
    self.cid = Atm.__counter
    Atm.counter = Atm.__counter + 1

  #utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter


    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
# Out:
# 138267207181344

# %%
Atm.get_counter()
# Out:
# 1

# %%
c2 = Atm()
# Out:
# 138267207506912

# %%
Atm.get_counter()
# Out:
# 1
